# %%
# Import dependancies
import pandas as pd
from wordcloud import WordCloud 
import matplotlib.pyplot as plt  
import plotly.express as px
import plotly.io as pio
import ast

# Set the float format to display pure numbers
pd.options.display.float_format = '{:.2f}'.format

# %%
# Read the csv file into a DataFrame
df = pd.read_csv("Data/processed_data.csv")

# Make sure the DataFrame populated correctly
df.head()
# Out:
#           id                                              title  year  rating  \
# 0  tt1502397                                  Bad Boys for Life  2020    6.50
# 1  tt8332922                              A Quiet Place Part II  2020    7.20
# 2  tt3794354                                 Sonic the Hedgehog  2020    6.50
# 3  tt7713068  Birds of Prey and the Fantabulous Emancipation...  2020    6.10
# 4  tt6673612                                           Dolittle  2020    5.60
#
#   votes       budget  gross_world_wide  gross_us_canada  \
# 0  187K  90000000.00      426505244.00     206305244.00
# 1  296K  61000000.00      297372261.00     160072261.00
# 2  171K  85000000.00      319715683.00     148974665.00
# 3  271K  84500000.00      205537933.00      84172791.00
# 4   73K 175000000.00      251410631.00      77047065.00
#
#    opening_weekend_gross                                             genres  \
# 0            62504105.00  ['Buddy Cop', 'Cop Drama', 'Action', 'Comedy',...
# 1            47547231.00  ['Alien Invasion', 'Monster Horror', 'Supernat...
# 2            58018348.00  ['Animal Adventure', 'Buddy Comedy', 'Road Tri...
# 3            33010017.00  ['Dark Comedy', 'Superhero', 'Action', 'Comedy...
# 4            21844045.00  ['Animal Adventure', 'Quest', 'Adventure', 'Co...
#
#                                 production_companies  wins  nominations  \
# 0  ['Columbia Pictures', '2.0 Entertainment', 'Do...     0           15
# 1  ['Paramount Pictures', 'Platinum Dunes', 'Sund...     0           44
# 2  ['Paramount Pictures', 'Sega Sammy Group', 'Or...     0           12
# 3  ['Clubhouse Pictures (II)', 'DC Entertainment'...     0           83
# 4  ['Universal Pictures', 'Perfect World Pictures...     0            9
#
#    oscars
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0

# %%
# Find the max and min for each table and display it for easy referencing
numeric_df = df[['rating', 'budget', 'gross_world_wide', 'gross_us_canada', 'opening_weekend_gross', 'wins', 'nominations', 'oscars']]

print(numeric_df.describe())
# Out:
#        rating          budget  gross_world_wide  gross_us_canada  \
# count 4378.00         4378.00           4378.00          4378.00
# mean     6.33    179240881.95       96560581.72      38619857.35
# std      1.02   4676916620.86      207366675.95      77711990.76
# min      1.30           20.00             95.00            95.00
# 25%      5.80      4639809.00        1835290.00        265761.25
# 50%      6.40     16000000.00       20622447.50       7633663.00
# 75%      7.00     45000000.00       90821281.25      42711708.75
# max      9.00 300000000000.00     2923706026.00     936662225.00
#
#        opening_weekend_gross    wins  nominations  oscars
# count                4378.00 4378.00      4378.00 4378.00
# mean             11694873.54    0.00        17.68    0.17
# std              24605966.57    0.00        39.26    0.67
# min                    11.00    0.00         0.00    0.00
# 25%                 37301.50    0.00         0.00    0.00
# 50%               1165404.50    0.00         4.00    0.00
# 75%              13147082.50    0.00        16.00    0.00
# max             357115007.00    0.00       433.00   10.00

# %%
most_nominations = df[df['nominations'] == 433]
most_nominations
# Out:
#              id   title  year  rating votes       budget  gross_world_wide  \
# 2780  tt1517268  Barbie  2023    6.80  585K 100000000.00     1446938421.00
#
#       gross_us_canada  opening_weekend_gross  \
# 2780     636238421.00           162022044.00
#
#                                                  genres  \
# 2780  ['High-Concept Comedy', 'Quirky Comedy', 'Sati...
#
#                                production_companies  wins  nominations  oscars
# 2780  ['Warner Bros.', 'Heyday Films', 'LuckyChap']     0          433       0

# %%
most_oscars = df[df['oscars'] == 10]
most_oscars
# Out:
#              id                       title  year  rating votes       budget  \
# 1301  tt1403865                   True Grit  2010    7.60  364K  38000000.00
# 2576  tt1800241             American Hustle  2013    7.20  507K  40000000.00
# 2812  tt5537002  Killers of the Flower Moon  2023    7.60  270K 200000000.00
#
#       gross_world_wide  gross_us_canada  opening_weekend_gross  \
# 1301      252278285.00     171243005.00            24830443.00
# 2576      251171807.00     150117807.00              740455.00
# 2812      158764012.00      68026901.00            23253655.00
#
#                                                  genres  \
# 1301               ['Period Drama', 'Drama', 'Western']
# 2576   ['Period Drama', 'True Crime', 'Crime', 'Drama']
# 2812  ['Epic', 'Period Drama', 'Tragedy', 'True Crim...
#
#                                    production_companies  wins  nominations  \
# 1301  ['Paramount Pictures', 'Skydance Media', 'Scot...     0          169
# 2576  ['Columbia Pictures', 'Annapurna Pictures', 'A...     0          227
# 2812  ['Apple Studios', 'Imperative Entertainment', ...     0          425
#
#       oscars
# 1301      10
# 2576      10
# 2812      10

# %%
fig = px.treemap(df,
                 path=['title', 'genres'],
                 values= 'gross_world_wide',
                 color= 'gross_world_wide',
                 color_continuous_scale='Greens',
                 title= 'Highest Earning Movies Treemap')

fig.update_layout(margin=dict(t=50, l=25, r=25, b=25))

fig.show()

# %%
top_50 = df.nlargest(50, 'gross_world_wide')

fig = px.treemap(top_50,
                 path=['title', 'genres'],
                 values= 'gross_world_wide',
                 color= 'gross_world_wide',
                 color_continuous_scale='Greens',
                 title= 'Highest Earning Movies Treemap')

fig.update_layout(margin=dict(t=50, l=25, r=25, b=25))

fig.show()

# %%
# Initialize an empty list to store unique genres
all_genres_unique = []

# Loop through each row of the 'Genres' column
for index, row in df.iterrows():
    # Check if 'Genres' is a list
    if isinstance(row['genres'], list):
        genres = row['genres']
    else:
        # Clean up the string if it's not a list (remove square brackets and extra quotes)
        genres = [genre.strip().strip("'").strip("[]") for genre in row['genres'].replace('[', '').replace(']', '').split(',')]

    # Loop through each genre in the current movie's genre list
    for genre in genres:
        # Check if the genre is already in the all_genres list
        if genre not in all_genres_unique:
            # If not, append the genre to the list
            all_genres_unique.append(genre)

# Output the final list of unique genres
print(all_genres_unique)
# Out:
# ['Buddy Cop', 'Cop Drama', 'Action', 'Comedy', 'Crime', 'Thriller', 'Alien Invasion', 'Monster Horror', 'Supernatural Horror', 'Drama', 'Horror', 'Sci-Fi', 'Animal Adventure', 'Buddy Comedy', 'Road Trip', 'Slapstick', 'Superhero', 'Supernatural Fantasy', 'Adventure', 'Family', 'Dark Comedy', 'Quest', 'Fantasy', 'Psychological Horror', 'Psychological Thriller', 'Suspense Mystery', 'Mystery', 'Adventure Epic', 'Mountain Adventure', 'Survival', 'Computer Animation', 'Epic', 'Fantasy Epic', 'Sword & Sorcery', 'Animation', 'Time Travel', 'Adult Animation', 'Anime', 'Dark Fantasy', 'Shōnen', 'Holiday', 'Teen Horror', 'Car Action', 'Romance', 'Disaster', 'Sea Adventure', 'Fairy Tale', 'Folk Horror', 'Witch Horror', 'Western', 'Coming-of-Age', 'Costume Drama', 'Feel-Good Romance', 'Period Drama', 'Romantic Comedy', 'Biography', 'Music', 'Body Swap Comedy', 'Slasher Horror', 'Teen Comedy', 'One-Person Army Action', 'Tragedy', 'Docudrama', 'Psychological Drama', 'Zombie Horror', 'Dystopian Sci-Fi', 'Teen Fantasy', 'Gangster', 'Tragic Romance', 'Musical', 'War Epic', 'History', 'War', 'Satire', 'Werewolf Horror', 'Whodunnit', 'Steamy Romance', 'Screwball Comedy', 'Quirky Comedy', 'Workplace Drama', 'Splatter Horror', 'Teen Drama', 'Teen Romance', 'Documentary', 'Space Sci-Fi', 'Sport', 'Action Epic', 'Drug Crime', 'Police Procedural', 'Jukebox Musical', 'Vampire Horror', 'True Crime', 'Baseball', 'Stop Motion Animation', 'Swashbuckler', 'Cyberpunk', 'Sci-Fi Epic', 'Concert', 'Music Documentary', 'Teen Adventure', 'Heist', 'Found Footage Horror', 'Serial Killer', 'Martial Arts', 'Caper', 'Conspiracy Thriller', 'Erotic Thriller', 'Soccer', 'Romantic Epic', 'Financial Drama', 'Dark Romance', 'Showbiz Drama', 'Extreme Sport', 'Water Sport', 'Political Thriller', 'Globetrotting Adventure', 'Raunchy Comedy', 'Crime Documentary', 'Faith & Spirituality Documentary', 'Political Documentary', 'Basketball', 'Sports Documentary', 'High-Concept Comedy', 'Jungle Adventure', 'Urban Adventure', 'Historical Epic', 'Parody', 'Pop Musical', 'Kaiju', 'Motorsport', 'Holiday Comedy', 'Artificial Intelligence', 'Cyber Thriller', 'Gun Fu', 'Political Drama', 'Farce', 'Spy', 'Desert Adventure', 'Holiday Animation', 'Holiday Family', 'Contemporary Western', 'Legal Drama', 'Hand-Drawn Animation', 'Legal Thriller', 'B-Horror', 'Mockumentary', 'Kung Fu', 'Boxing', 'Sword & Sandal', 'Stoner Comedy', 'Medical Drama', 'Body Horror', 'Slice of Life', 'B-Action', 'Football', 'Wuxia', 'Cozy Mystery', 'Dinosaur Adventure', 'Holiday Romance', 'Rock Musical', 'Korean Drama', 'Shōjo', 'Prison Drama', 'Nature Documentary', 'Western Epic', 'Military Documentary', 'History Documentary', 'Science & Technology Documentary', 'Sketch Comedy', 'Isekai', 'Bumbling Detective', 'Iyashikei', 'Samurai', 'News', 'Steampunk', 'Hard-boiled Detective', 'Travel Documentary', 'Sitcom', 'Stand-Up', 'Talk Show']

# %%
# Initialize an empty list to store all genres
all_genres_whole = []

# Loop through each row of the 'Genres' column
for index, row in df.iterrows():
    # Check if 'Genres' is a list
    if isinstance(row['genres'], list):
        genres = row['genres']
    else:
        # Clean up the string if it's not a list (remove square brackets and extra quotes)
        genres = [genre.strip().strip("'").strip("[]") for genre in row['genres'].replace('[', '').replace(']', '').split(',')]

    # Add genres to the all_genres list
    all_genres_whole.extend(genres)

# Convert all_genres list to a pandas Series and count the occurrences of each genre
genre_counts = pd.Series(all_genres_whole).value_counts()

# Get the top 20 genres
top_10_genres = genre_counts.head(20)

# Output the top 20 genres
print(top_10_genres)
# Out:
# Drama           2518
# Comedy          1533
# Thriller        1216
# Action          1051
# Romance          910
# Adventure        813
# Crime            701
# Mystery          576
# Fantasy          559
# Horror           526
# Sci-Fi           486
# Family           455
# Biography        394
# History          282
# Dark Comedy      254
# Animation        248
# Period Drama     200
# War              197
# Documentary      185
# Music            178
# Name: count, dtype: int64

# %%
genres_count = len(all_genres_unique)
print(genres_count)
# Out:
# 180

# %%
# Initialize an empty list to store all genres
all_companies_whole = []

# Loop through each row of the 'Genres' column
for index, row in df.iterrows():
    # Check if 'Genres' is a list
    if isinstance(row['production_companies'], list):
        companies = row['production_companies']
    else:
        # Clean up the string if it's not a list (remove square brackets and extra quotes)
        companies = [genre.strip().strip("'").strip("[]") for genre in row['production_companies'].replace('[', '').replace(']', '').split(',')]

    # Add genres to the all_genres list
    all_companies_whole.extend(companies)

# Convert all_genres list to a pandas Series and count the occurrences of each genre
companies_counts = pd.Series(all_companies_whole).value_counts()

# Get the top 20 genres
top_10_companies = companies_counts.head(20)

# Output the top 20 genres
print(top_10_companies)
# Out:
# Universal Pictures           204
# Warner Bros.                 197
# Columbia Pictures            178
# Paramount Pictures           146
# Walt Disney Pictures         102
# Relativity Media             102
# New Line Cinema               99
# Twentieth Century Fox         99
# Lionsgate                     94
# Metro-Goldwyn-Mayer (MGM)     77
# Summit Entertainment          70
# New Regency Productions       60
# Screen Gems                   59
# StudioCanal                   57
# Dreamworks Pictures           56
# Focus Features                55
# Blumhouse Productions         52
# Legendary Entertainment       52
# Village Roadshow Pictures     51
# Film4                         45
# Name: count, dtype: int64
